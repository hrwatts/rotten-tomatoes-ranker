# %% [markdown]
# # Rotten Tomatoes Ranker Quickstart
#
# This notebook runs a small sample scrape through the canonical entrypoint.

# %% [markdown]
# Recommended before running:
#
# - install `requirements.txt`
# - run `playwright install chromium`
# - prefer the terminal script if Playwright has trouble inside Jupyter

# %%
# %run ../scripts/build_dataset.py --out ../data/generated/rt_movies.csv --limit 100 --workers 8 --min-year 1970 --min-tomato 60
